# %%
#importing the important libraries

#Data Analysis And Data Visualization Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset
data=pd.read_csv("pulsar_stars.csv")


#checking the head of the data
data.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
#getting the info og the data types

#how much memory your dataset is taking in your memory

#data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  Mean of the integrated profile                  17898 non-null float64
#  Standard deviation of the integrated profile    17898 non-null float64
#  Excess kurtosis of the integrated profile       17898 non-null float64
#  Skewness of the integrated profile              17898 non-null float64
#  Mean of the DM-SNR curve                        17898 non-null float64
#  Standard deviation of the DM-SNR curve          17898 non-null float64
#  Excess kurtosis of the DM-SNR curve             17898 non-null float64
#  Skewness of the DM-SNR curve                    17898 non-null float64
# target_class                                     17898 non-null int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %%
#describing data include the statistics and other important measures
data.describe()
# Out:
#         Mean of the integrated profile  \
# count                     17898.000000
# mean                        111.079968
# std                          25.652935
# min                           5.812500
# 25%                         100.929688
# 50%                         115.078125
# 75%                         127.085938
# max                         192.617188
#
#         Standard deviation of the integrated profile  \
# count                                   17898.000000
# mean                                       46.549532
# std                                         6.843189
# min                                        24.772042
# 25%                                        42.376018
# 50%                                        46.947479
# 75%                                        51.023202
# max                                        98.778911
#
#         Excess kurtosis of the integrated profile  \
# count                                17898.000000
# mean                                     0.477857
# std                                      1.064040
# min                                     -1.876011
# 25%                                      0.027098
# 50%                                      0.223240
# 75%                                      0.473325
# max                                      8.069522
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# count                         17898.000000               17898.000000
# mean                              1.770279                  12.614400
# std                               6.167913                  29.472897
# min                              -1.791886                   0.213211
# 25%                              -0.188572                   1.923077
# 50%                               0.198710                   2.801839
# 75%                               0.927783                   5.464256
# max                              68.101622                 223.392140
#
#         Standard deviation of the DM-SNR curve  \
# count                             17898.000000
# mean                                 26.326515
# std                                  19.470572
# min                                   7.370432
# 25%                                  14.437332
# 50%                                  18.461316
# 75%                                  28.428104
# max                                 110.642211
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# count                          17898.000000                   17898.000000
# mean                               8.303556                     104.857709
# std                                4.506092                     106.514540
# min                               -3.139270                      -1.976976
# 25%                                5.781506                      34.960504
# 50%                                8.433515                      83.064556
# 75%                               10.702959                     139.309331
# max                               34.539844                    1191.000837
#
#        target_class
# count  17898.000000
# mean       0.091574
# std        0.288432
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
#seeing the number of unique values in the label variable variable
data.target_class.unique()
# Out:
# array([0, 1])

# %%
#counting the value also
data.target_class.value_counts()
# Out:
# 0    16259
# 1     1639
# Name: target_class, dtype: int64

# %%
#checking the shape of the data

# %%
print("There are {} rows and {} columns".format(data.shape[0],data.shape[1]))
# Out:
# There are 17898 rows and 9 columns

# %%
data.rename(columns={ ' Mean of the integrated profile':'mean_profile', ' Standard deviation of the integrated profile':'std_profile', 
                     ' Excess kurtosis of the integrated profile':'kurt_profile', ' Skewness of the integrated profile':'skew_profile',
                     ' Mean of the DM-SNR curve':'mean_dmsnr_curve', ' Standard deviation of the DM-SNR curve':'std_dmsnr_curve',
                     ' Excess kurtosis of the DM-SNR curve':'kurt_dmsnr_curve', ' Skewness of the DM-SNR curve': 'skew_dmsnr_curve'}, inplace=True)

data.head()
# Out:
#    mean_profile  std_profile  kurt_profile  skew_profile  mean_dmsnr_curve  \
# 0    140.562500    55.683782     -0.234571     -0.699648          3.199833
# 1    102.507812    58.882430      0.465318     -0.515088          1.677258
# 2    103.015625    39.341649      0.323328      1.051164          3.121237
# 3    136.750000    57.178449     -0.068415     -0.636238          3.642977
# 4     88.726562    40.672225      0.600866      1.123492          1.178930
#
#    std_dmsnr_curve  kurt_dmsnr_curve  skew_dmsnr_curve  target_class
# 0        19.110426          7.975532         74.242225             0
# 1        14.860146         10.576487        127.393580             0
# 2        21.744669          7.735822         63.171909             0
# 3        20.959280          6.896499         53.593661             0
# 4        11.468720         14.269573        252.567306             0

# %%
sns.countplot(data["target_class"])

# %%
#General plotting of the data

# %%
#imbalanced class
from sklearn.model_selection import train_test_split
X=data.iloc[:,:-1].values
y=data.iloc[:,8].values

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Simple BAse Model
#support vector machines
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
classifier=SVC(kernel='linear',random_state=0)
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
cm=confusion_matrix(y_test,y_pred)
accuracy_score(y_test,y_pred)
# Out:
# 0.9829608938547486

# %%
ax=sns.heatmap(cm,annot=True,cmap="Greens")
bottom,top=ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)
# Out:
# (2.0, 0.0)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3306
#            1       0.93      0.84      0.88       274
#
#     accuracy                           0.98      3580
#    macro avg       0.96      0.92      0.94      3580
# weighted avg       0.98      0.98      0.98      3580

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier(n_estimators=100,random_state=0)
y_pred=classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
cm=confusion_matrix(y_test,y_pred)

# %%
ax=sns.heatmap(cm,annot=True,cmap='Blues')
bottom,top=ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)
# Out:
# (2.0, 0.0)

# %%
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 0.9846368715083799
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3306
#            1       0.94      0.86      0.90       274
#
#     accuracy                           0.98      3580
#    macro avg       0.96      0.93      0.94      3580
# weighted avg       0.98      0.98      0.98      3580

# %%
data.head()
# Out:
#    mean_profile  std_profile  kurt_profile  skew_profile  mean_dmsnr_curve  \
# 0    140.562500    55.683782     -0.234571     -0.699648          3.199833
# 1    102.507812    58.882430      0.465318     -0.515088          1.677258
# 2    103.015625    39.341649      0.323328      1.051164          3.121237
# 3    136.750000    57.178449     -0.068415     -0.636238          3.642977
# 4     88.726562    40.672225      0.600866      1.123492          1.178930
#
#    std_dmsnr_curve  kurt_dmsnr_curve  skew_dmsnr_curve  target_class
# 0        19.110426          7.975532         74.242225             0
# 1        14.860146         10.576487        127.393580             0
# 2        21.744669          7.735822         63.171909             0
# 3        20.959280          6.896499         53.593661             0
# 4        11.468720         14.269573        252.567306             0

# %%
#importing the standard Scalar
from sklearn.preprocessing import StandardScaler

#import the train_test_split method
from sklearn.model_selection import train_test_split

# %%
#Plotting the pairplot which has both sctterplot and the distribution plot
sns.pairplot(data=data, vars=data.columns.values[:-1],hue='target_class')

# %%
#plotting the distribution plot 
#for all the numerical attributes that are present
#using sns distplot
fig = plt.figure(figsize=(25, 25))

fig1 = fig.add_subplot(421)
sns.distplot(data.mean_profile, color='r')

fig2 = fig.add_subplot(422)
sns.distplot(data.std_profile, color='g')

fig3 = fig.add_subplot(423)
sns.distplot(data.kurt_profile, color='b')

fig4 = fig.add_subplot(424)
sns.distplot(data.skew_profile, color='y')

fig5 = fig.add_subplot(425)
sns.distplot(data.mean_dmsnr_curve, color='purple')

fig6 = fig.add_subplot(426)
sns.distplot(data.std_dmsnr_curve, color='grey')

fig6 = fig.add_subplot(427)
sns.distplot(data.kurt_dmsnr_curve, color='black')

fig6 = fig.add_subplot(428)
sns.distplot(data.skew_dmsnr_curve, color='orange')

# %%
#Gradient boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier
classifier=GradientBoostingClassifier()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3275,   31],
#        [  33,  241]])

# %%
ax=sns.heatmap(cm,annot=True,cmap='Blues')
bottom,top=ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)
# Out:
# (2.0, 0.0)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3306
#            1       0.89      0.88      0.88       274
#
#     accuracy                           0.98      3580
#    macro avg       0.94      0.94      0.94      3580
# weighted avg       0.98      0.98      0.98      3580

# %%
#printing the accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.982122905027933

# %%
#importing the library
from xgboost import XGBClassifier

# %%
#building the Xgb Boost classifier
xgb=XGBClassifier()
xgb.fit(X_train,y_train)
y_pred=xgb.predict(X_test)

# %%
#calculating the confusion matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[3286,   20],
#        [  36,  238]])

# %%
#plotting the confusion Matrix using the heatmap
ax=sns.heatmap(cm,annot=True,cmap='Blues')
bottom,top=ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)
# Out:
# (2.0, 0.0)

# %%
#printing the accuracy score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9843575418994414

# %%
#printing the classification report 

#which contains Precision
#recall
#f1-score
#support
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3306
#            1       0.92      0.87      0.89       274
#
#     accuracy                           0.98      3580
#    macro avg       0.96      0.93      0.94      3580
# weighted avg       0.98      0.98      0.98      3580
